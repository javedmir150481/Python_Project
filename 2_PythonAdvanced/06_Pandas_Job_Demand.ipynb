# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
# Top trensind jobs in USA
df_usa = df[df["job_country"] == "United States"].copy()
df_usa.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 5         Data Engineer                                  GCP Data Engineer
# 6  Senior Data Engineer                  Senior Data Engineer  - GCP Cloud
# 9        Data Scientist                                  Data Scientist II
#
#       job_location            job_via         job_schedule_type  \
# 0    Watertown, CT    via Work Nearby                 Full-time
# 3  San Antonio, TX  via Diversity.com                 Full-time
# 5         Anywhere   via ZipRecruiter  Contractor and Temp work
# 6     Dearborn, MI       via LinkedIn                 Full-time
# 9         Anywhere   via ZipRecruiter                 Full-time
#
#    job_work_from_home          search_location     job_posted_date  \
# ...

# %%
df_usa["job_posted_month"] = df_usa["job_posted_date"].dt.strftime("%B")
df_usa
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 3              Data Engineer
# 5              Data Engineer
# 6       Senior Data Engineer
# 9             Data Scientist
# ...                      ...
# 785673        Data Scientist
# 785685          Data Analyst
# 785692        Data Scientist
# 785703          Data Analyst
# 785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 5                                       GCP Data Engineer          Anywhere
# 6                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 9                                       Data Scientist II          Anywhere
# ...                                                   ...               ...
# ...

# %%
df_usa_pivot = df_usa.pivot_table(
    index="job_posted_month", 
    columns="job_title_short", 
    aggfunc="size"
)
df_usa_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# April                          565              40          6049
# August                         903              39          6634
# December                       648              40          3979
# February                       447              24          6124
# January                        527              36          8494
# July                           581              39          5201
# June                           446              32          5683
# March                          438              19          6218
# May                            279              20          4993
# November                       719              36          4531
# October                        932              48          5271
# September                      897              50          4639
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
df_usa_pivot.reset_index(inplace=True)
df_usa_pivot["month_no"] = pd.to_datetime(df_usa_pivot['job_posted_month'], format="%B").dt.month

# %%
df_usa_pivot
# Out:
# job_title_short job_posted_month  Business Analyst  Cloud Engineer  \
# 0                          April               565              40
# 1                         August               903              39
# 2                       December               648              40
# 3                       February               447              24
# 4                        January               527              36
# 5                           July               581              39
# 6                           June               446              32
# 7                          March               438              19
# 8                            May               279              20
# 9                       November               719              36
# 10                       October               932              48
# 11                     September               897              50
#
# job_title_short  Data Analyst  Data Engineer  Data Scientist  \
# ...

# %%
df_usa_pivot.sort_values("month_no", inplace=True)
df_usa_pivot.set_index("job_posted_month", inplace=True)
df_usa_pivot.drop(columns="month_no", inplace=True)


df_usa_pivot.plot(kind="line")
# Out:
# <Axes: xlabel='job_posted_month'>

# %%
top_3 = df_usa["job_title_short"].value_counts().head(3)
top_3 = top_3.index.to_list()
df_usa_pivot[top_3].plot(kind="line")
plt.title('Monthly Job Postings for Top Data Jobs in the US')
plt.xlabel('2023')
plt.ylabel('Job Count')
plt.legend()
plt.show()

# %%
# Top trending jobs in India
df_india_new = df[df["job_country"] == "India"].copy()
df_india_new.head()
# Out:
#          job_title_short                                    job_title  \
# 16         Data Engineer                            Big Data Engineer
# 19        Data Scientist                               Data Scientist
# 29        Data Scientist                               Data Scientist
# 38          Data Analyst        Data Quality and Governance Analyst 1
# 42  Senior Data Engineer  Senior Data Engineer(Python)-1563,1637&1633
#
#                   job_location  \
# 16    Pune, Maharashtra, India
# 19    Pune, Maharashtra, India
# 29    Pune, Maharashtra, India
# 38                       India
# 42  Chennai, Tamil Nadu, India
#
#                                               job_via job_schedule_type  \
# 16                                       via LinkedIn         Full-time
# 19                                         via Indeed         Full-time
# 29                                         via Exusia         Full-time
# ...

# %%
df_india_new["job_posted_month"] = df_india_new["job_posted_date"].dt.to_period("M")
df_india_new.head()
# Out:
#          job_title_short                                    job_title  \
# 16         Data Engineer                            Big Data Engineer
# 19        Data Scientist                               Data Scientist
# 29        Data Scientist                               Data Scientist
# 38          Data Analyst        Data Quality and Governance Analyst 1
# 42  Senior Data Engineer  Senior Data Engineer(Python)-1563,1637&1633
#
#                   job_location  \
# 16    Pune, Maharashtra, India
# 19    Pune, Maharashtra, India
# 29    Pune, Maharashtra, India
# 38                       India
# 42  Chennai, Tamil Nadu, India
#
#                                               job_via job_schedule_type  \
# 16                                       via LinkedIn         Full-time
# 19                                         via Indeed         Full-time
# 29                                         via Exusia         Full-time
# ...

# %%
df_pivot = df_india_new.pivot_table(
    index="job_posted_month",
    columns="job_title_short",
    aggfunc="size"
)
df_pivot.head()
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# 2023-01                        175              31           628
# 2023-02                        143              35           433
# 2023-03                        116              37           422
# 2023-04                        170              32           418
# 2023-05                        103              14           278
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# 2023-01                    2132            1444                         70
# 2023-02                    1631             932                         42
# 2023-03                    1591            1005                         34
# 2023-04                    1566             946                         54
# 2023-05                    1384             837                         31
#
# job_title_short   Senior Data Analyst  Senior Data Engineer  \
# job_posted_month
# ...

# %%
top_3 = df["job_title_short"].value_counts().head(3)
top_3 = top_3.index.to_list()
df_pivot[top_3].plot(kind="line")
plt.title('Monthly Job Postings for Top Data Jobs in the India')
plt.xlabel('2023')
plt.ylabel('Job Count')
plt.legend()
plt.show()

# %%
# For html5 charts I have installed plotly
from plotly.tools import mpl_to_plotly
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

fig_matplotlib = df_pivot[top_3].plot().get_figure()
fig_plotly = mpl_to_plotly(fig_matplotlib)

fig_plotly.show()

# %%
# This conversion to plotly is done using chatgpt using matplotlib conversion.
from plotly.tools import mpl_to_plotly
import warnings

warnings.filterwarnings("ignore", category=UserWarning)

# Convert matplotlib → plotly
fig_matplotlib = df_pivot[top_3].plot().get_figure()
fig_plotly = mpl_to_plotly(fig_matplotlib)

# ✅ Improve layout for HTML display
fig_plotly.update_layout(
    title="Monthly Job Postings for Top Data Jobs in India",
    
    # Chart size
    width=1000,
    height=600,
    
    # Axis labels
    xaxis_title="Year (2023)",
    yaxis_title="Job Count",
    
    # Legend formatting
    legend=dict(
    orientation="v",
    x=1.02,
    y=1
    ),
    
    # Margins
    margin=dict(l=60, r=40, t=80, b=60),
    
    # Theme
    template="plotly_white"
)

# Optional: improve line appearance
for trace in fig_plotly.data:
    trace.update(mode="lines+markers")

# Show chart
fig_plotly.show()

# %%
# This need to be fixed but the tooltip seem to be fixed
from plotly.tools import mpl_to_plotly
import warnings
import pandas as pd

warnings.filterwarnings("ignore", category=UserWarning)

# FIX: convert pivot index (NOT original df)
df_pivot.index = pd.to_datetime(df['job_posted_date']).head(12)

# Convert matplotlib → plotly
fig_matplotlib = df_pivot[top_3].plot().get_figure()
fig_plotly = mpl_to_plotly(fig_matplotlib)

# FIX: assign correct x-axis
for trace in fig_plotly.data:
    trace.x = df_pivot.index

# Layout improvements
fig_plotly.update_layout(
    xaxis=dict(type="date"),
    title="Monthly Job Postings for Top Data Jobs in India",
    width=1000,
    height=600,
    xaxis_title="Year (2023)",
    yaxis_title="Job Count",
    # Legend formatting
    legend=dict(
    orientation="v",
    x=1.02,
    y=1
    ),
    margin=dict(t=120),
    template="plotly_white"
)

fig_plotly.show()
