# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# DataFrame Copy
df_original = df.copy()
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %%
df.sample()
# Out:
#        job_title_short                  job_title job_location       job_via  \
# 508150    Data Analyst  BI Data Warehouse Analyst  Chicago, IL  via LinkedIn
#
#        job_schedule_type  job_work_from_home          search_location  \
# 508150         Full-time               False  Illinois, United States
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 508150 2023-06-27 11:02:34                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 508150  United States         NaN              NaN              NaN
#
#        company_name                              job_skills  \
# 508150       Kemper  ['sql', 'oracle', 'snowflake', 'jira']
#
#                                           job_type_skills
# 508150  {'async': ['jira'], 'cloud': ['oracle', 'snowf...

# %%
df.sample(10)
# Out:
#               job_title_short                                job_title  \
# 766661  Senior Data Scientist                    Senior Data Scientist
# 257338      Software Engineer                Iga IT Governance Analyst
# 320062  Senior Data Scientist                    Senior Data Scientist
# 470640           Data Analyst     Research Data and Laboratory Analyst
# 689905           Data Analyst  Data and Statistical Analyst/Researcher
# 629452   Senior Data Engineer                     Senior Data Engineer
# 684938           Data Analyst            Data Analyst, Medical Devices
# 49633          Data Scientist                     Data Labeling Expert
# 600764         Data Scientist                           Data Scientist
# 52393            Data Analyst                             Data Analyst
#
#                                          job_location  \
# 766661                                   Oakhurst, CA
# 257338                                    Doha, Qatar
# 320062                                Oxfordshire, UK
# 470640                            Fort Lauderdale, FL
# 689905                   Dubai - United Arab Emirates
# 629452  Vilnius, Vilnius City Municipality, Lithuania
# 684938                                      Argentina
# 49633                       Ho Chi Minh City, Vietnam
# 600764                                 Warsaw, Poland
# 52393                                     Philippines
#
#                                               job_via job_schedule_type  \
# 766661                                      via BeBee         Full-time
# 257338                             via BeBee دولة قطر         Full-time
# 320062                                  via WTRF Jobs         Full-time
# 470640                                   via LinkedIn         Full-time
# 689905                                     via Indeed         Full-time
# 629452                                   via LinkedIn         Full-time
# 684938  via Trabajo.org - Vacantes De Empleo, Trabajo         Full-time
# 49633                                 via Trabajo.org         Full-time
# 600764                                   via LinkedIn         Full-time
# 52393                                 via Trabajo.org         Full-time
#
#         job_work_from_home            search_location     job_posted_date  \
# 766661               False  California, United States 2023-09-12 01:03:14
# 257338               False                      Qatar 2023-12-16 07:28:42
# 320062               False             United Kingdom 2023-05-31 17:19:17
# 470640               False     Florida, United States 2023-11-22 14:02:39
# 689905               False       United Arab Emirates 2023-04-04 10:45:39
# 629452               False                  Lithuania 2023-10-22 12:34:31
# 684938               False                  Argentina 2023-10-07 10:40:09
# 49633                False                    Vietnam 2023-11-01 06:29:41
# 600764               False                     Poland 2023-10-17 09:23:15
# 52393                False                Philippines 2023-12-23 06:35:08
#
#         job_no_degree_mention  job_health_insurance           job_country  \
# 766661                  False                 False         United States
# 257338                  False                 False                 Qatar
# 320062                  False                 False        United Kingdom
# 470640                  False                 False         United States
# 689905                  False                 False  United Arab Emirates
# 629452                   True                 False             Lithuania
# 684938                  False                 False             Argentina
# 49633                   False                 False               Vietnam
# 600764                  False                 False                Poland
# 52393                    True                 False           Philippines
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 766661         NaN              NaN              NaN
# 257338         NaN              NaN              NaN
# 320062         NaN              NaN              NaN
# 470640         NaN              NaN              NaN
# 689905         NaN              NaN              NaN
# 629452         NaN              NaN              NaN
# 684938         NaN              NaN              NaN
# 49633          NaN              NaN              NaN
# 600764         NaN              NaN              NaN
# 52393          NaN              NaN              NaN
#
#                                        company_name  \
# 766661                           Resource Logistics
# 257338                                       Brunel
# 320062                          In Technology Group
# 470640                            Ascendo Resources
# 689905                                        KCORP
# 629452                                       Railsr
# 684938    International Consulting Associates, Inc.
# 49633                                     CODE LEAP
# 600764                                   mBank S.A.
# 52393   Collabera Technologies Private Limited Inc.
#
#                                                job_skills  \
# 766661  ['python', 'pandas', 'nltk', 'tableau', 'micro...
# 257338                                                NaN
# 320062                                    ['python', 'r']
# 470640                   ['unix', 'excel', 'spreadsheet']
# 689905  ['python', 'spss', 'excel', 'word', 'powerpoin...
# 629452  ['c', 'java', 'c#', 'python', 'aws', 'azure', ...
# 684938                                                NaN
# 49633                                                 NaN
# 600764   ['python', 'sql', 'spark', 'hadoop', 'power bi']
# 52393              ['python', 'sql', 'excel', 'power bi']
#
#                                           job_type_skills
# 766661  {'analyst_tools': ['tableau', 'microstrategy',...
# 257338                                                NaN
# 320062                   {'programming': ['python', 'r']}
# 470640  {'analyst_tools': ['excel', 'spreadsheet'], 'o...
# 689905  {'analyst_tools': ['spss', 'excel', 'word', 'p...
# 629452  {'cloud': ['aws', 'azure', 'gcp', 'databricks'...
# 684938                                                NaN
# 49633                                                 NaN
# 600764  {'analyst_tools': ['power bi'], 'libraries': [...
# 52393   {'analyst_tools': ['excel', 'power bi'], 'prog...

# %%
df.sample(10, random_state=42)
# Out:
#               job_title_short  \
# 502901   Senior Data Engineer
# 406337  Senior Data Scientist
# 659951          Data Engineer
# 541593           Data Analyst
# 425158   Senior Data Engineer
# 183426           Data Analyst
# 287790           Data Analyst
# 541983           Data Analyst
# 416896         Data Scientist
# 780907          Data Engineer
#
#                                                 job_title  \
# 502901                               Senior Data Engineer
# 406337                          Senior Analytics Engineer
# 659951                                      Data Engineer
# 541593                                       Data Analyst
# 425158  Senior Data Engineer. Job in Amsterdam NBC4i Jobs
# 183426                                       Data Analyst
# 287790                                       Data Analyst
# 541983                   Data Analyst, Cloud Systems Jobs
# 416896             Alternant Actuariat & Data Science H/F
# 780907              Data Engineer with Fivetran,Qlik Must
#
#                      job_location                 job_via job_schedule_type  \
# 502901                St Paul, MN               via BeBee         Full-time
# 406337                 London, UK            via LinkedIn         Full-time
# 659951    Newcastle upon Tyne, UK              via Indeed         Full-time
# 541593                      Malta         via Trabajo.org         Full-time
# 425158     Amsterdam, Netherlands          via NBC4i Jobs         Full-time
# 183426                  Singapore  via Singapore | JobsDB         Full-time
# 287790                  Tampa, FL            via LinkedIn         Full-time
# 541983              Chantilly, VA      via Clearance Jobs         Full-time
# 416896                     France            via LinkedIn         Full-time
# 780907  Mexico City, CDMX, Mexico        via BeBee México         Full-time
#
#         job_work_from_home         search_location     job_posted_date  \
# 502901               False  Florida, United States 2023-12-17 11:09:06
# 406337               False          United Kingdom 2023-10-06 16:09:56
# 659951               False          United Kingdom 2023-09-06 10:11:25
# 541593               False                   Malta 2023-02-14 21:14:18
# 425158               False             Netherlands 2023-06-19 16:34:30
# 183426               False               Singapore 2023-11-09 16:07:57
# 287790               False  Florida, United States 2023-07-14 17:02:23
# 541983               False                 Georgia 2023-06-15 19:44:34
# 416896               False                  France 2023-09-22 16:47:24
# 780907               False                  Mexico 2023-01-16 06:19:09
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 502901                  False                 False   United States
# 406337                  False                 False  United Kingdom
# 659951                   True                 False  United Kingdom
# 541593                   True                 False           Malta
# 425158                   True                 False     Netherlands
# 183426                  False                 False       Singapore
# 287790                   True                 False   United States
# 541983                  False                 False   United States
# 416896                  False                 False          France
# 780907                  False                 False          Mexico
#
#        salary_rate  salary_year_avg  salary_hour_avg            company_name  \
# 502901         NaN              NaN              NaN           ManpowerGroup
# 406337         NaN              NaN              NaN                 Harnham
# 659951         NaN              NaN              NaN             Morgan King
# 541593         NaN              NaN              NaN                 Konnekt
# 425158         NaN              NaN              NaN  Independent Recruiters
# 183426         NaN              NaN              NaN    FLEXOSENSE PTE. LTD.
# 287790         NaN              NaN              NaN      Iris Software Inc.
# 541983         NaN              NaN              NaN                    SAIC
# 416896         NaN              NaN              NaN             KPMG France
# 780907         NaN              NaN              NaN        CORUS Consulting
#
#                                                job_skills  \
# 502901                            ['sql', 'azure', 'git']
# 406337  ['sql', 'python', 'bigquery', 'snowflake', 'lo...
# 659951                                                NaN
# 541593                                           ['jira']
# 425158                                         ['python']
# 183426  ['r', 'python', 'java', 'sql', 'sql server', '...
# 287790                         ['sql', 'hadoop', 'excel']
# 541983  ['sql', 'r', 'matlab', 'python', 'oracle', 'aw...
# 416896                                                NaN
# 780907  ['oracle', 'snowflake', 'aws', 'azure', 'alter...
#
#                                           job_type_skills
# 502901  {'cloud': ['azure'], 'other': ['git'], 'progra...
# 406337  {'analyst_tools': ['looker'], 'cloud': ['bigqu...
# 659951                                                NaN
# 541593                                {'async': ['jira']}
# 425158                        {'programming': ['python']}
# 183426  {'analyst_tools': ['tableau'], 'cloud': ['orac...
# 287790  {'analyst_tools': ['excel'], 'libraries': ['ha...
# 541983  {'analyst_tools': ['power bi', 'tableau', 'qli...
# 416896                                                NaN
# 780907  {'analyst_tools': ['alteryx'], 'cloud': ['orac...

# %%
# Id you use copy() method, it will have a different id. If you use df = df_altered, it will have the same id
# So its better to use copy() method
df_altered = df_original
df_altered.loc[:5, "salary_year_avg"]
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %%
# Calculating the median salary
median_salary = df_altered['salary_year_avg'].median()

# Filling the missing values with the median salary
df_altered['salary_year_avg'] = df_altered.loc[:,'salary_year_avg'].fillna(median_salary)

# %%
df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary)

# %%
df_altered.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df_original.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
print('ID of df_original:               ', id(df_original))
print('ID of df_altered:                ', id(df_altered))
print('Are the two dataframes the same? ', id(df_original) == id(df_altered))
# Out:
# ID of df_original:                14207404624
# ID of df_altered:                 14207404624
# Are the two dataframes the same?  True

# %%
f_original = df.copy()
df_altered = df_original.copy()

print('ID of df_original:               ', id(df_original))
print('ID of df_altered:                ', id(df_altered))
print('Are the two dataframes the same? ', id(df_original) == id(df_altered))
# Out:
# ID of df_original:                14207404624
# ID of df_altered:                 14205028624
# Are the two dataframes the same?  False

# %%
# Calculating the median salary
median_salary = df_altered['salary_year_avg'].median()

# Filling the missing values with the median salary
df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary)

df_altered.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
# This is wrong, check it why
df_original.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64
